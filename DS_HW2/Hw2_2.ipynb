# %% [markdown]
# Частина друга: Аналіз файлів

# %% [markdown]
# Прочитайте файл 2017_jun_final.csv за допомогою методу read_csv

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

url = "https://drive.google.com/file/d/1JMYqXipZpz9Y5-vyxvLEO2Y1sRBxqu-U/view"
url = "https://drive.google.com/uc?id=" + url.split("/")[-2]
df = pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8704 entries, 0 to 8703
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   N                                 8704 non-null   int64
#  1   Должность                         8704 non-null   object
#  2   Язык.программирования             4854 non-null   object
#  3   Специализация                     1485 non-null   object
#  4   Общий.опыт.работы                 8704 non-null   object
#  5   Опыт.работы.на.текущем.месте      8704 non-null   object
#  6   Зарплата.в.месяц                  8704 non-null   int64
#  7   Изменение.зарплаты.за.12.месяцев  8704 non-null   int64
#  8   Город                             8704 non-null   object
#  9   Размер.компании                   8704 non-null   object
#  10  Тип.компании                      8704 non-null   object
# ...

# %%
sns.set_style("whitegrid")
plt.title('Залежність заробітної плати від посади')
sns.set(font_scale=0.5)
sns.stripplot(data=df, x='Должность', y='Зарплата.в.месяц', hue='Должность')
plt.show()

# %% [markdown]
# Прочитайте отриману таблицю, використовуючи метод head

# %%
df.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %% [markdown]
# Визначте розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (8704, 25)

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
df.dtypes
# Out:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
print("Частка пропусків в колонці:")
for column in df.columns:
    print(f"{column}  {((df[column].isnull().sum()/ len(df[column])) * 100).round(2)}%")
# Out:
# Частка пропусків в колонці:
# N  0.0%
# Должность  0.0%
# Язык.программирования  44.23%
# Специализация  82.94%
# Общий.опыт.работы  0.0%
# Опыт.работы.на.текущем.месте  0.0%
# Зарплата.в.месяц  0.0%
# Изменение.зарплаты.за.12.месяцев  0.0%
# Город  0.0%
# Размер.компании  0.0%
# Тип.компании  0.0%
# Пол  0.0%
# Возраст  0.0%
# Образование  0.0%
# Университет  4.11%
# Еще.студент  0.0%
# Уровень.английского  0.0%
# Предметная.область  2.56%
# Дата.заполнения  0.0%
# User.Agent  0.0%
# exp  0.0%
# current_job_exp  0.0%
# salary  0.0%
# Валюта  99.89%
# cls  18.08%

# %% [markdown]
# Видаліть усі стовпці з пропусками, крім стовпця "Мова програмування"

# %%
df['Язык.программирования'].fillna('temp', inplace=True)
df = df.dropna(axis=1)
df['Язык.программирования'].replace('temp', np.nan, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4854 entries, 2 to 8703
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   N                                 4854 non-null   int64
#  1   Должность                         4854 non-null   object
#  2   Язык.программирования             4854 non-null   object
#  3   Общий.опыт.работы                 4854 non-null   object
#  4   Опыт.работы.на.текущем.месте      4854 non-null   object
#  5   Зарплата.в.месяц                  4854 non-null   int64
#  6   Изменение.зарплаты.за.12.месяцев  4854 non-null   int64
#  7   Город                             4854 non-null   object
#  8   Размер.компании                   4854 non-null   object
#  9   Тип.компании                      4854 non-null   object
#  10  Пол                               4854 non-null   object
# ...

# %% [markdown]
# Знову порахуйте, яка частка пропусків міститься в кожній колонці і переконайтеся, що залишився тільки стовпець "Мова.програмування"

# %%
print("Частка пропусків в колонці:")
for column in df.columns:
    print(f"{column}  {((df[column].isnull().sum()/ len(df[column])) * 100).round(2)}%")
# Out:
# Частка пропусків в колонці:
# N  0.0%
# Должность  0.0%
# Язык.программирования  0.0%
# Общий.опыт.работы  0.0%
# Опыт.работы.на.текущем.месте  0.0%
# Зарплата.в.месяц  0.0%
# Изменение.зарплаты.за.12.месяцев  0.0%
# Город  0.0%
# Размер.компании  0.0%
# Тип.компании  0.0%
# Пол  0.0%
# Возраст  0.0%
# Образование  0.0%
# Еще.студент  0.0%
# Уровень.английского  0.0%
# Дата.заполнения  0.0%
# User.Agent  0.0%
# exp  0.0%
# current_job_exp  0.0%
# salary  0.0%

# %% [markdown]
# Видаліть усі рядки у вихідній таблиці за допомогою методу dropna

# %%
df = df.dropna()

# %% [markdown]
# Визначте новий розмір таблиці за допомогою методу shape

# %%
df.shape
# Out:
# (4854, 20)

# %% [markdown]
# Створіть нову таблицю python_data, в якій будуть тільки рядки зі спеціалістами, які вказали мову програмування Python

# %%
python_data = df[df['Язык.программирования'] == 'Python'].copy()
python_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207 entries, 12 to 8695
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   N                                 207 non-null    int64
#  1   Должность                         207 non-null    object
#  2   Язык.программирования             207 non-null    object
#  3   Общий.опыт.работы                 207 non-null    object
#  4   Опыт.работы.на.текущем.месте      207 non-null    object
#  5   Зарплата.в.месяц                  207 non-null    int64
#  6   Изменение.зарплаты.за.12.месяцев  207 non-null    int64
#  7   Город                             207 non-null    object
#  8   Размер.компании                   207 non-null    object
#  9   Тип.компании                      207 non-null    object
#  10  Пол                               207 non-null    object
# ...

# %%
study_data = df.groupby('Образование')
study_data = study_data.agg({"Зарплата.в.месяц": 'mean'})
sns.barplot(data=study_data, y='Зарплата.в.месяц', x=study_data.index)
plt.title('Середня зарплата програмістів, залежно від освіти')
plt.xticks(rotation=90)
plt.show()

# %%
data_pie=python_data['Должность'].value_counts()
plt.title('Розподіл Python програмістів за спеціалізацією')
plt.pie(
    data_pie,
    labels=data_pie.index,
    autopct="%.2f%%",
    explode=[0.05, 0.05, 0.05, 0.05, 0.05],
    shadow=True
)
plt.show()

# %% [markdown]
# Визначте розмір таблиці python_data за допомогою методу shape

# %%
python_data.shape
# Out:
# (207, 20)

# %% [markdown]
# Використовуючи метод groupby, виконайте групування за стовпчиком "Посада"

# %%
grouped_data = python_data.groupby('Должность')

# %% [markdown]
# Створіть новий DataFrame, де для згрупованих даних за стовпчиком "Посада", виконайте агрегацію даних за допомогою методу agg і знайдіть мінімальне та максимальне значення у стовпчику "Зарплата.в.місяць"

# %%
salary_data = grouped_data.agg({'Зарплата.в.месяц': ['min', 'max']})
salary_data
# Out:
#                          Зарплата.в.месяц
#                                       min   max
# Должность
# Junior Software Engineer              100  1250
# Senior Software Engineer             1300  9200
# Software Engineer                     500  5400
# System Architect                     3000  5000
# Technical Lead                       1425  6200

# %% [markdown]
# Створіть функцію fill_avg_salary, яка повертатиме середнє значення заробітної плати на місяць. Використовуйте її для методу apply та створіть новий стовпчик "avg"

# %%
def fill_avg_salary(row):
    return row.mean()

salary_data['avg'] = salary_data['Зарплата.в.месяц'].apply(fill_avg_salary, axis=1)
salary_data
# Out:
#                          Зарплата.в.месяц           avg
#                                       min   max
# Должность
# Junior Software Engineer              100  1250   675.0
# Senior Software Engineer             1300  9200  5250.0
# Software Engineer                     500  5400  2950.0
# System Architect                     3000  5000  4000.0
# Technical Lead                       1425  6200  3812.5

# %% [markdown]
# Створіть описову статистику за допомогою методу describe для нового стовпчика.

# %%
salary_data['avg'].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: avg, dtype: float64

# %% [markdown]
# Збережіть отриману таблицю в CSV файл

# %%
salary_data.to_csv('python_salary.csv', header=['min', 'max', 'avg'])
data = pd.read_csv('python_salary.csv')
data
# Out:
#                   Должность   min   max     avg
# 0  Junior Software Engineer   100  1250   675.0
# 1  Senior Software Engineer  1300  9200  5250.0
# 2         Software Engineer   500  5400  2950.0
# 3          System Architect  3000  5000  4000.0
# 4            Technical Lead  1425  6200  3812.5
